# %%
# Step 1: Import the library
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#Step 2: Set up the document corpus

d1="petrol cars are cheaper than diesel cars"

d2="diesel is cheaper than petrol"

# %%
doc_corpus=[d1,d2]

# %%
print(doc_corpus)
# Out:
# ['petrol cars are cheaper than diesel cars', 'diesel is cheaper than petrol']

# %%
# Step 3: Initialize TfidfVectorizer and print the feature names

# %%
vec=TfidfVectorizer(stop_words='english')
matrix=vec.fit_transform(doc_corpus)
print("Feature Names n",vec.get_feature_names_out())
# Out:
# Feature Names n ['cars' 'cheaper' 'diesel' 'petrol']

# %%
# Step 4: Generate a sparse matrix with tf-idf values
print("Sparse Matrix n",matrix.shape,"n",matrix.toarray())
# Out:
# Sparse Matrix n (2, 4) n [[0.85135433 0.30287281 0.30287281 0.30287281]
#  [0.         0.57735027 0.57735027 0.57735027]]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
doc1="petrol cars are cheaper than diesel cars"
doc2="diesel is cheaper than petrol"
doc_corpus=[doc1,doc2]
print(doc_corpus)
vec=TfidfVectorizer(stop_words='english',ngram_range=(1,3),max_features=10)
matrix=vec.fit_transform(doc_corpus)
print("Feature Names n",vec.get_feature_names_out())
print("Sparse Matrix n",matrix.shape,"n",matrix.toarray())
# Out:
# ['petrol cars are cheaper than diesel cars', 'diesel is cheaper than petrol']
# Feature Names n ['cars' 'cars cheaper' 'cars cheaper diesel' 'cheaper' 'cheaper diesel'
#  'cheaper diesel cars' 'cheaper petrol' 'diesel' 'diesel cars' 'petrol']
# Sparse Matrix n (2, 10) n [[0.61666358 0.30833179 0.30833179 0.21938061 0.30833179 0.30833179
#   0.         0.21938061 0.30833179 0.21938061]
#  [0.         0.         0.         0.44832087 0.         0.
#   0.63009934 0.44832087 0.         0.44832087]]

# %%
doc_corpus[0]
# Out:
# 'petrol cars are cheaper than diesel cars'
